# %% [markdown]
# #### plot the SBM loglikelihood as a function of theta, the jump around theta=-1 means the metadata of faction doesn't align with the optimal community structure, the leader-fellow is the optimal partition.

# %%
import matplotlib.pyplot as plt
plt.style.use('seaborn-white')

# %%
import disp_output as do
do.plotLq('karate','karate_faction')
# Out:
# /Users/kate/anaconda3/lib/python3.7/site-packages/matplotlib/pyplot.py:1442: UserWarning: Attempted to set non-positive left xlim on a log-scaled axis.
# Invalid limit will be ignored.
#   ret = ax.set_xlim(*args, **kwargs)

# %% [markdown]
# #### implement the neoSBM on a synthetic network, but the plot here is not same as the one shown in Leto's paper.

# %%
import matplotlib.pyplot as plt
plt.style.use('seaborn-white')
import disp_output as do
do.plotLq("synth2","synth2_local_assort_labels")
# Out:
# /Users/kate/anaconda3/lib/python3.7/site-packages/matplotlib/pyplot.py:1442: UserWarning: Attempted to set non-positive left xlim on a log-scaled axis.
# Invalid limit will be ignored.
#   ret = ax.set_xlim(*args, **kwargs)

# %% [markdown]
# #### implement the neoSBM on the malaria var gene network at locus one, using UPS metadata (3-0, others remain), the plot is a slight ly different from the one offered.

# %%
import matplotlib.pyplot as plt
plt.style.use('seaborn-white')
import disp_output as do
do.plotLq("HVR_1","metadata_UPS")
# Out:
# /Users/kate/anaconda3/lib/python3.7/site-packages/matplotlib/pyplot.py:1442: UserWarning: Attempted to set non-positive left xlim on a log-scaled axis.
# Invalid limit will be ignored.
#   ret = ax.set_xlim(*args, **kwargs)

# %% [markdown]
# #### implement the neoSBM on the malaria var gene network at locus one, using UPS metadata (1-0, 2-1, 3-2), the output are same as before which are different from the one in paper

# %%
import matplotlib.pyplot as plt
plt.style.use('seaborn-white')
import disp_output as do
do.plotLq("HVR_1","metadata_UPS2")
# Out:
# /Users/kate/anaconda3/lib/python3.7/site-packages/matplotlib/pyplot.py:1442: UserWarning: Attempted to set non-positive left xlim on a log-scaled axis.
# Invalid limit will be ignored.
#   ret = ax.set_xlim(*args, **kwargs)

# %% [markdown]
# #### implement the neoSBM on the malaria var gene network at locus six, using UPS metadata (1 2 3-0 1 2), the result is consistent with the one given in Leto's paper

# %%
import matplotlib.pyplot as plt
plt.style.use('seaborn-white')
import disp_output as do
do.plotLq("HVR_6","metadata_UPS2")
# Out:
# /Users/kate/anaconda3/lib/python3.7/site-packages/matplotlib/pyplot.py:1442: UserWarning: Attempted to set non-positive left xlim on a log-scaled axis.
# Invalid limit will be ignored.
#   ret = ax.set_xlim(*args, **kwargs)
